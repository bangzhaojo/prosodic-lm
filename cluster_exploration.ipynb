# %%
import pandas as pd
import os
import itertools
from tqdm import tqdm
import joblib 
import json
import warnings

warnings.simplefilter("ignore", category=UserWarning)

# %%
merge_directory = "/shared/3/projects/bangzhao/prosodic_embeddings/merge/output_phones/"
output_dir = "/shared/3/projects/bangzhao/prosodic_embeddings/merge/output_jsonl_files/"

# %%
kmeans200 = joblib.load("/shared/3/projects/bangzhao/prosodic_embeddings/merge/clustering/kmeans_10000epi_200clu.pkl")

# %%
files = [f for f in os.listdir(merge_directory) if os.path.isfile(os.path.join(merge_directory, f))]

filename = files[0]
file_path = os.path.join(merge_directory, filename)

data = pd.read_csv(file_path)
X = data[['F0semitoneFrom27.5Hz_sma3nz', 'F1frequency_sma3nz', 'mfcc1_sma3', 'mfcc2_sma3', 
          'mfcc3_sma3', 'mfcc4_sma3', 'F0semitoneFrom27.5Hz_sma3nzSlope', 'F1frequency_sma3nzSlope',
          'mfcc1_sma3Slope', 'mfcc2_sma3Slope', 'mfcc3_sma3Slope', 'mfcc4_sma3Slope']]

# %%
prosody_id_200 = kmeans200.predict(X)

# %%
data['cluster'] = prosody_id_200

# %%
data.head(50)
# Out:
#     index  start   end content    Type            Speaker  \
# 0     307   0.03  0.74     AY1  phones  cache_240_4083523
# 1     308   0.74  0.77       M  phones  cache_240_4083523
# 2     309   2.09  2.12       T  phones  cache_240_4083523
# 3     310   2.12  2.32     IH1  phones  cache_240_4083523
# 4     311   2.32  2.58       F  phones  cache_240_4083523
# 5     312   2.58  2.67     AE1  phones  cache_240_4083523
# 6     313   2.67  2.80       L  phones  cache_240_4083523
# 7     314   2.80  2.83     AH0  phones  cache_240_4083523
# 8     315   2.83  2.87       N  phones  cache_240_4083523
# 9     316   2.87  2.91       W  phones  cache_240_4083523
# 10    317   2.91  2.95     IH0  phones  cache_240_4083523
# 11    318   2.95  2.98      DH  phones  cache_240_4083523
# 12    319   2.98  3.01      DH  phones  cache_240_4083523
# 13    320   3.01  3.05     AH0  phones  cache_240_4083523
# 14    321   3.05  4.06     spn  phones  cache_240_4083523
# ...

# %%
data[-10:]
# Out:
#       index   start     end content    Type            Speaker  \
# 1281   1588  118.29  118.32       Z  phones  cache_240_4083523
# 1282   1589  118.32  118.38       B  phones  cache_240_4083523
# 1283   1590  118.38  118.42     IH0  phones  cache_240_4083523
# 1284   1591  118.42  118.46       N  phones  cache_240_4083523
# 1285   1592  118.46  118.51     AH0  phones  cache_240_4083523
# 1286   1593  118.51  119.12     spn  phones  cache_240_4083523
# 1287   1594  119.12  119.16       N  phones  cache_240_4083523
# 1288   1595  119.16  119.33     UW1  phones  cache_240_4083523
# 1289   1596  119.33  119.38       Z  phones  cache_240_4083523
# 1290   1597  119.38  119.89     spn  phones  cache_240_4083523
#
#       F0semitoneFrom27.5Hz_sma3nz  F1frequency_sma3nz  mfcc1_sma3  mfcc2_sma3  \
# 1281                    20.041475         1152.839844    0.684659   29.038290
# 1282                    16.328970          700.549398   19.478331   19.059897
# ...

# %%
"Z-binuh (pause) news (pause)(153)"
# Out:
# 'Z-binuh (pause) news (pause)(153)'

# %%
data[90:110]
# Out:
#      index  start    end content    Type            Speaker  \
# 90     397   9.70   9.76       M  phones  cache_240_4083523
# 91     398   9.76   9.82     OW0  phones  cache_240_4083523
# 92     399   9.82   9.97       S  phones  cache_240_4083523
# 93     400   9.97  10.01     EH1  phones  cache_240_4083523
# 94     401  10.01  10.07       K  phones  cache_240_4083523
# 95     402  10.07  10.19      SH  phones  cache_240_4083523
# 96     403  10.19  10.31     UW2  phones  cache_240_4083523
# 97     404  10.31  10.32     AH0  phones  cache_240_4083523
# 98     405  10.32  10.36       L  phones  cache_240_4083523
# 99     406  10.36  10.45       Z  phones  cache_240_4083523
# 100    407  10.45  10.48     AH0  phones  cache_240_4083523
# 101    408  10.48  10.51       N  phones  cache_240_4083523
# 102    409  10.51  10.54       D  phones  cache_240_4083523
# 103    410  10.54  11.49     spn  phones  cache_240_4083523
# 104    411  11.92  12.03       S  phones  cache_240_4083523
# ...

# %%
"homosexuals an(153)d (pause) (7) senator"
# Out:
# 'homosexuals an(153)d (pause) (7) senator'

# %%
data[120:140]
# Out:
#      index  start    end content    Type            Speaker  \
# 120    427  13.29  13.34     AH0  phones  cache_240_4083523
# 121    428  13.34  13.42       Z  phones  cache_240_4083523
# 122    429  13.42  13.47     UH1  phones  cache_240_4083523
# 123    430  13.47  13.61       R  phones  cache_240_4083523
# 124    431  13.61  13.70     IY0  phones  cache_240_4083523
# 125    432  13.70  13.96     AO1  phones  cache_240_4083523
# 126    433  13.96  14.04       N  phones  cache_240_4083523
# 127    434  14.04  14.13       T  phones  cache_240_4083523
# 128    435  14.13  14.16       Y  phones  cache_240_4083523
# 129    436  14.16  14.26     UW1  phones  cache_240_4083523
# 130    437  14.26  14.31       Z  phones  cache_240_4083523
# 131    438  14.31  14.37       D  phones  cache_240_4083523
# 132    439  14.37  14.51     EY2  phones  cache_240_4083523
# 133    440  14.79  14.88       K  phones  cache_240_4083523
# 134    441  14.88  15.01     AO1  phones  cache_240_4083523
# ...

# %%
"Missouri on Tu(153)e(153)sday c(7)alled for..."
# Out:
# 'Missouri on Tu(153)e(153)sday c(7)alled for...'

# %%
data[data['cluster']==153]
# Out:
#       index   start     end content    Type            Speaker  \
# 7       314    2.80    2.83     AH0  phones  cache_240_4083523
# 44      351    6.82    6.87     IH0  phones  cache_240_4083523
# 80      387    9.08    9.11     AH0  phones  cache_240_4083523
# 101     408   10.48   10.51       N  phones  cache_240_4083523
# 107     414   12.13   12.16     AH0  phones  cache_240_4083523
# 128     435   14.13   14.16       Y  phones  cache_240_4083523
# 129     436   14.16   14.26     UW1  phones  cache_240_4083523
# 165     472   16.78   16.88     AH1  phones  cache_240_4083523
# 206     513   20.51   20.54     AO1  phones  cache_240_4083523
# 209     516   20.68   20.71       D  phones  cache_240_4083523
# 224     531   21.92   21.95     AH0  phones  cache_240_4083523
# 229     536   22.28   22.31     IY1  phones  cache_240_4083523
# 237     544   22.86   22.89     EH0  phones  cache_240_4083523
# 239     546   22.92   22.95       T  phones  cache_240_4083523
# ...

# %%
data[data['cluster']==7]
# Out:
#       index   start     end content    Type            Speaker  \
# 12      319    2.98    3.01      DH  phones  cache_240_4083523
# 14      321    3.05    4.06     spn  phones  cache_240_4083523
# 32      339    6.03    6.07       T  phones  cache_240_4083523
# 63      370    8.12    8.15       L  phones  cache_240_4083523
# 68      375    8.36    8.39       T  phones  cache_240_4083523
# 103     410   10.54   11.49     spn  phones  cache_240_4083523
# 133     440   14.79   14.88       K  phones  cache_240_4083523
# 149     456   15.71   15.76       N  phones  cache_240_4083523
# 153     460   16.04   16.07     AH0  phones  cache_240_4083523
# 176     483   18.15   18.42      HH  phones  cache_240_4083523
# 196     503   19.87   19.91       V  phones  cache_240_4083523
# 211     518   20.75   20.89       S  phones  cache_240_4083523
# 232     539   22.41   22.48       L  phones  cache_240_4083523
# 247     554   23.40   23.43      DH  phones  cache_240_4083523
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the DataFrame (assuming it's already available as 'df')
# Example placeholder for data loading
# df = pd.read_csv("your_data.csv")

df = data
# Plot setup
plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['F0semitoneFrom27.5Hz_sma3nz'], df['F1frequency_sma3nz'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 153]
plt.scatter(cluster_153['F0semitoneFrom27.5Hz_sma3nz'], cluster_153['F1frequency_sma3nz'], 
            label='Cluster 153')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 7]
plt.scatter(cluster_7['F0semitoneFrom27.5Hz_sma3nz'], cluster_7['F1frequency_sma3nz'], 
            label='Cluster 7')

# Highlight cluster 7
cluster_69 = df[df['cluster'] == 69]
plt.scatter(cluster_69['F0semitoneFrom27.5Hz_sma3nz'], cluster_69['F1frequency_sma3nz'], 
            label='Cluster 69')

# Labels and legend
plt.xlabel('F0semitoneFrom27.5Hz_sma3nz')
plt.ylabel('F1frequency_sma3nz')
plt.title('Scatter Plot Highlighting Clusters 153 and 7')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the DataFrame if available
# Assuming df is available in the environment

# Plot setup
plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['F0semitoneFrom27.5Hz_sma3nzSlope'], df['F1frequency_sma3nzSlope'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 153]
plt.scatter(cluster_153['F0semitoneFrom27.5Hz_sma3nzSlope'], cluster_153['F1frequency_sma3nzSlope'], 
            label='Cluster 153')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 7]
plt.scatter(cluster_7['F0semitoneFrom27.5Hz_sma3nzSlope'], cluster_7['F1frequency_sma3nzSlope'], 
            label='Cluster 7')

# Highlight cluster 7
cluster_69 = df[df['cluster'] == 69]
plt.scatter(cluster_69['F0semitoneFrom27.5Hz_sma3nzSlope'], cluster_69['F1frequency_sma3nzSlope'], 
            label='Cluster 69')

# Labels and legend
plt.xlabel('F0semitoneFrom27.5Hz_sma3nzSlope')
plt.ylabel('F1frequency_sma3nzSlope')
plt.title('Slope Feature Scatter Plot Highlighting Clusters 153 and 7')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot setup
plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['mfcc1_sma3Slope'], df['mfcc2_sma3Slope'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 153]
plt.scatter(cluster_153['mfcc1_sma3Slope'], cluster_153['mfcc2_sma3Slope'], 
            label='Cluster 153')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 7]
plt.scatter(cluster_7['mfcc1_sma3Slope'], cluster_7['mfcc2_sma3Slope'], 
            label='Cluster 7')

# Highlight cluster 69
cluster_69 = df[df['cluster'] == 69]
plt.scatter(cluster_69['mfcc1_sma3Slope'], cluster_69['mfcc2_sma3Slope'], 
            label='Cluster 69')

# Labels and legend
plt.xlabel('mfcc1_sma3Slope')
plt.ylabel('mfcc2_sma3Slope')
plt.title('Slope Feature Scatter Plot Highlighting Clusters 153, 7, and 69')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot setup
plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['mfcc3_sma3Slope'], df['mfcc4_sma3Slope'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 153]
plt.scatter(cluster_153['mfcc3_sma3Slope'], cluster_153['mfcc4_sma3Slope'], 
            label='Cluster 153')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 7]
plt.scatter(cluster_7['mfcc3_sma3Slope'], cluster_7['mfcc4_sma3Slope'], 
            label='Cluster 7')

# Highlight cluster 69
cluster_69 = df[df['cluster'] == 69]
plt.scatter(cluster_69['mfcc3_sma3Slope'], cluster_69['mfcc4_sma3Slope'], 
            label='Cluster 69')

# Labels and legend
plt.xlabel('mfcc3_sma3Slope')
plt.ylabel('mfcc4_sma3Slope')
plt.title('MFCC Slope Feature Scatter Plot Highlighting Clusters 153, 7, and 69')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Wait for the user to upload the data file to define df
# Placeholder for plotting if df were defined

# Example plotting code
plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['mfcc1_sma3'], df['mfcc2_sma3'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 153]
plt.scatter(cluster_153['mfcc1_sma3'], cluster_153['mfcc2_sma3'], 
            label='Cluster 153')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 7]
plt.scatter(cluster_7['mfcc1_sma3'], cluster_7['mfcc2_sma3'], 
            label='Cluster 7')

# Highlight cluster 7
cluster_69 = df[df['cluster'] == 69]
plt.scatter(cluster_69['mfcc1_sma3'], cluster_69['mfcc2_sma3'], 
            label='Cluster 69')

# Labels and legend
plt.xlabel('mfcc1_sma3')
plt.ylabel('mfcc2_sma3')
plt.title('MFCC Feature Scatter Plot Highlighting Clusters 153 and 7')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Wait for the user to upload the data file to define df
# Example plotting code assuming df is defined

plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['mfcc3_sma3'], df['mfcc4_sma3'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 153]
plt.scatter(cluster_153['mfcc3_sma3'], cluster_153['mfcc4_sma3'], 
            label='Cluster 153')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 7]
plt.scatter(cluster_7['mfcc3_sma3'], cluster_7['mfcc4_sma3'], 
            label='Cluster 7')

# Highlight cluster 7
cluster_69 = df[df['cluster'] == 69]
plt.scatter(cluster_69['mfcc3_sma3'], cluster_69['mfcc4_sma3'], 
            label='Cluster 69')

# Labels and legend
plt.xlabel('mfcc3_sma3')
plt.ylabel('mfcc4_sma3')
plt.title('MFCC3 vs MFCC4 Highlighting Clusters 153 and 7')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cluster 50

# %%
kmeans50 = joblib.load("/shared/3/projects/bangzhao/prosodic_embeddings/merge/clustering/kmeans_10000epi_50clu.pkl")

# %%
files = [f for f in os.listdir(merge_directory) if os.path.isfile(os.path.join(merge_directory, f))]

filename = files[0]
file_path = os.path.join(merge_directory, filename)

data = pd.read_csv(file_path)
X = data[['F0semitoneFrom27.5Hz_sma3nz', 'F1frequency_sma3nz', 'mfcc1_sma3', 'mfcc2_sma3', 
          'mfcc3_sma3', 'mfcc4_sma3', 'F0semitoneFrom27.5Hz_sma3nzSlope', 'F1frequency_sma3nzSlope',
          'mfcc1_sma3Slope', 'mfcc2_sma3Slope', 'mfcc3_sma3Slope', 'mfcc4_sma3Slope']]

# %%
prosody_id_50 = kmeans50.predict(X)

# %%
data['cluster'] = prosody_id_50

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = data

# Load the DataFrame if available
# Assuming df is available in the environment

# Plot setup
plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['F0semitoneFrom27.5Hz_sma3nzSlope'], df['F1frequency_sma3nzSlope'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 1]
plt.scatter(cluster_153['F0semitoneFrom27.5Hz_sma3nzSlope'], cluster_153['F1frequency_sma3nzSlope'], 
            label='Cluster 1')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 39]
plt.scatter(cluster_7['F0semitoneFrom27.5Hz_sma3nzSlope'], cluster_7['F1frequency_sma3nzSlope'], 
            label='Cluster 39')

# Highlight cluster 7
cluster_69 = df[df['cluster'] == 38]
plt.scatter(cluster_69['F0semitoneFrom27.5Hz_sma3nzSlope'], cluster_69['F1frequency_sma3nzSlope'], 
            label='Cluster 38')

# Labels and legend
plt.xlabel('F0semitoneFrom27.5Hz_sma3nzSlope')
plt.ylabel('F1frequency_sma3nzSlope')
plt.title('Slope Feature Scatter Plot Highlighting Clusters 153 and 7')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot setup
plt.figure(figsize=(10, 6))

# Plot all points in light gray
plt.scatter(df['mfcc1_sma3Slope'], df['mfcc2_sma3Slope'], 
            c='lightgray', label='Other Clusters', alpha=0.5)

# Highlight cluster 153
cluster_153 = df[df['cluster'] == 1]
plt.scatter(cluster_153['mfcc1_sma3Slope'], cluster_153['mfcc2_sma3Slope'], 
            label='Cluster 1')

# Highlight cluster 7
cluster_7 = df[df['cluster'] == 39]
plt.scatter(cluster_7['mfcc1_sma3Slope'], cluster_7['mfcc2_sma3Slope'], 
            label='Cluster 39')

# Highlight cluster 69
cluster_69 = df[df['cluster'] == 38]
plt.scatter(cluster_69['mfcc1_sma3Slope'], cluster_69['mfcc2_sma3Slope'], 
            label='Cluster 38')

# Labels and legend
plt.xlabel('mfcc1_sma3Slope')
plt.ylabel('mfcc2_sma3Slope')
plt.title('Slope Feature Scatter Plot Highlighting Clusters 153, 7, and 69')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
