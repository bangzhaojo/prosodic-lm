# %%
import pandas as pd
import os
import itertools
from tqdm import tqdm

# %%
merge_directory = "/shared/3/projects/bangzhao/prosodic_embeddings/merge/output_phones/"

# %%
entry_count = 0
with os.scandir(merge_directory) as entries:
    for entry in tqdm(entries, desc="Counting entries", unit="item"):
        entry_count += 1

print(f"Total number of items in the folder: {entry_count}")
# Out:
# Counting entries: 444630item [00:06, 65807.39item/s]
# Total number of items in the folder: 444630

# %%
with os.scandir(merge_directory) as entries:
    first_5_files = [entry.name for entry in itertools.islice(entries, 5) if entry.is_file()]

# %%
data = pd.read_csv(merge_directory + first_5_files[1])

# %%
data
# Out:
#       index   start     end content    Type            Speaker  \
# 0       328    0.79    0.89      HH  phones  cache_240_4083523
# 1       329    0.89    0.94     AH0  phones  cache_240_4083523
# 2       330    0.94    1.01       L  phones  cache_240_4083523
# 3       331    1.01    1.27     OW1  phones  cache_240_4083523
# 4       332    1.44    1.47     AH0  phones  cache_240_4083523
# ...     ...     ...     ...     ...     ...                ...
# 1287   1615  162.99  163.10       S  phones  cache_240_4083523
# 1288   1616  163.10  163.27     UW1  phones  cache_240_4083523
# 1289   1617  163.27  163.35       N  phones  cache_240_4083523
# 1290   1618  164.48  164.53       B  phones  cache_240_4083523
# 1291   1619  164.53  164.89     AY1  phones  cache_240_4083523
#
#       F0semitoneFrom27.5Hz_sma3nz  F1frequency_sma3nz  mfcc1_sma3  mfcc2_sma3  \
# 0                        2.009054          466.540685   11.523029    7.739447
# 1                       45.235821          886.231974   25.546735   -9.858777
# 2                       43.419835          812.817871   35.463306   -7.925060
# 3                       33.985452          706.109560   43.106290    1.457174
# 4                       15.385923          578.595773   34.773227   19.221015
# ...                           ...                 ...         ...         ...
# 1287                    14.415867          398.995076    1.164869   37.957955
# 1288                    46.085821          822.218845   34.485400   -3.033425
# 1289                    15.713736          787.463114   39.488567   23.606769
# 1290                     6.534406          881.298613   24.446177   19.564723
# 1291                    40.311737          812.006422   43.327634    1.707948
#
#       mfcc3_sma3  mfcc4_sma3  F0semitoneFrom27.5Hz_sma3nzSlope  \
# 0      10.319337    6.502726                          8.358064
# 1      -7.841492  -28.672811                         -3.884697
# 2      -7.907924  -36.702930                        -60.758400
# 3       2.078861  -24.462177                        -67.097290
# 4      14.158550   -4.260828                         37.624528
# ...          ...         ...                               ...
# 1287   16.334741   -4.851757                         22.203001
# 1288   12.586581  -45.483325                          9.275974
# 1289   20.515843   -6.397824                        582.272911
# 1290   25.140559   11.937395                         -6.783154
# 1291   10.682635  -26.041159                         21.693058
#
#       F1frequency_sma3nzSlope  mfcc1_sma3Slope  mfcc2_sma3Slope  \
# 0                 1056.857083        26.292229         5.967052
# 1                 1108.795166       415.475154      -250.586051
# 2                -4612.498474       104.601860       -39.764714
# 3                 -509.285493        10.877387       159.357356
# 4                 1386.308344       -43.631413        38.239404
# ...                       ...              ...              ...
# 1287              -411.971697      -135.263246      -136.739791
# 1288              1073.758596        49.192626      -108.539342
# 1289             -3287.866211       -93.193054       115.039921
# 1290               164.286350        -7.542963        -3.098070
# 1291              -110.078863       -62.811431        48.687789
#
#       mfcc3_sma3Slope  mfcc4_sma3Slope
# 0           19.202083         8.450661
# 1         -389.543283      -507.355547
# 2          -42.314458      -252.320719
# 3          158.904269        68.446663
# 4           51.177905        73.390730
# ...               ...              ...
# 1287      -223.147446        -0.373841
# 1288        36.630584        56.246319
# 1289       115.208387       326.158595
# 1290         2.739028        13.581138
# 1291        94.538764       -38.524990
#
# [1292 rows x 18 columns]
