# %%
import json
import pandas as pd
import numpy as np
import random
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, adjusted_mutual_info_score

# %%
sample_path = "/shared/3/projects/bangzhao/prosodic_embeddings/sample/10k_episodes_10k_chunks_sampled_clean.csv"

# %%
sampled_df = pd.read_csv(sample_path)

# %%
sampled_df.head()
# Out:
#     content  F0semitoneFrom27.5Hz_sma3nz  F1frequency_sma3nz  mfcc1_sma3  \
# 0        of                    13.372669          709.972252   17.627483
# 1  february                    25.560986          526.965713   32.997189
# 2       but                     6.901864          743.787904    8.244580
# 3      does                    10.564279          691.468026   10.707017
# 4      that                    30.806327          526.894130   24.568225
#
#    mfcc2_sma3  mfcc3_sma3  mfcc4_sma3  F0semitoneFrom27.5Hz_sma3nzSlope  \
# 0   11.882088   16.337697    3.473034                       -538.578081
# 1    5.850077   11.350032   -3.486887                        -61.509885
# 2    5.885458   13.293003   -0.155409                         28.414856
# 3    7.465867   12.070202   -3.605176                         31.394321
# 4   -1.291678   16.486000  -25.644237                          4.176154
#
#    F1frequency_sma3nzSlope  mfcc1_sma3Slope  mfcc2_sma3Slope  mfcc3_sma3Slope  \
# 0              6524.478912      -376.016708       164.729478       230.000696
# 1              -235.190234        69.452360        23.128781       -40.124914
# 2              -217.811986        19.415308        -8.778166        -1.277758
# 3              -324.730716        12.486669       -11.226081         2.389543
# 4               209.619455        -7.214032       -14.171904       -11.736863
#
#    mfcc4_sma3Slope
# 0       300.470206
# 1        -8.078765
# 2       -55.507402
# 3       -34.655392
# 4       -21.604156

# %%
sampled_df = sampled_df[['content', 'mfcc1_sma3', 'mfcc2_sma3', 'mfcc3_sma3', 'mfcc4_sma3', 
           'F0semitoneFrom27.5Hz_sma3nz', 'F1frequency_sma3nz']].dropna()

# %%
X = sampled_df[['mfcc1_sma3', 'mfcc2_sma3', 'mfcc3_sma3', 'mfcc4_sma3', 
           'F0semitoneFrom27.5Hz_sma3nz', 'F1frequency_sma3nz']]

# %%
kmeans1 = KMeans(n_clusters=1000, init='k-means++', random_state=42)
kmeans1.fit(X)

import joblib
print(joblib.__version__)
joblib.dump(kmeans1, '/shared/3/projects/bangzhao/prosodic_embeddings/sample/kmeans_plusplus_1k_1000.pkl')
