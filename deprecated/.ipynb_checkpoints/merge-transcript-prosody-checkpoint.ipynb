# %%
import os
import pandas as pd
import json
import sys
import re

# prosody
import time
import numpy as np
import audb
import audiofile
import opensmile

import requests
import subprocess
import warnings
from sklearn.linear_model import LinearRegression
import multiprocessing
from multiprocessing import Manager

# %%
def standardize_name(name):
    return re.sub("[^\w\d.]","", name)


# Function to read the nth line and load it as a JSON object
def read_nth_line_as_json(file_path, n):
    try:
        with open(file_path, 'r') as file:
            for i, line in enumerate(file):
                if i == n - 1:  # Since line numbering starts from 0, we use n - 1
                    # Parse the line as a JSON object
                    return json.loads(line)
        return f"Line {n} does not exist in the file."
    except json.JSONDecodeError as json_err:
        return f"Error decoding JSON: {json_err}"
    except Exception as e:
        return f"Error reading the file: {e}"
    

def download_and_convert(json_object, name, download_directory):
    """Download MP3, save transcript, and convert MP3 to WAV."""
    
    mp3_url = json_object['enclosure']
    
    try:
        # Download MP3
        mp3_filename = os.path.join(download_directory, f"{name}.mp3")
        response = requests.get(mp3_url, stream=True)
        if response.status_code == 200:
            with open(mp3_filename, 'wb') as mp3_file:
                for chunk in response.iter_content(chunk_size=8192):
                    mp3_file.write(chunk)
            # print(f"Downloaded MP3: {mp3_filename}")
        else:
            # print(f"Failed to download MP3 {mp3_url}, status code: {response.status_code}")
            return False

        # Convert MP3 to WAV
        wav_filename = os.path.join(download_directory, name + '.wav')
        command = ['ffmpeg', '-y', '-i', mp3_filename, wav_filename]
        subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        os.remove(mp3_filename)
        # print(f"Converted MP3 to WAV and removed original MP3: {mp3_filename}")

        return True

    except Exception as e:
        # print(f"Failed to process {name}: {e}")
        return False
    
    
def extract_prosody(wav_path, out_path):
    signal, sampling_rate = audiofile.read(
        wav_path,
        always_2d=True,
    )

    #note increasing num_workers doesn't seem to help much here 
    smile = opensmile.Smile(
        feature_set=opensmile.FeatureSet.eGeMAPSv02,
        feature_level=opensmile.FeatureLevel.LowLevelDescriptors, 
        num_workers=1, 
        multiprocessing=True
    )

    df = smile.process_signal(
        signal,
        sampling_rate
    )
    # df.to_csv(out_path + "LowLevel.csv")
    return df


def addMicroseconds(inStr): 
    if "." not in inStr: 
        return inStr + ".000000"  # Add microseconds if they are missing
    else: 
        return inStr

    
def getSlope(inList): 
    if len(inList) < 2:  # If there are fewer than 2 points, return 0
        return 0
    
    x = list(np.arange(0, (len(inList)*.02)-.01, .02))  # Create time points at intervals of 0.02 seconds
    x = np.array(x).reshape(-1, 1)
    y = np.array(inList).reshape(-1, 1)
    
    # Fit a linear regression line and return the slope (rate of change)
    lr = LinearRegression(fit_intercept=True).fit(x, y)
    coef = lr.coef_.item()
    return coef

# %%
def merge_prosody_transcript(prosodydf, transcriptdf, name, file_index, output_directory):
    try:
        print(f"Processing: {name}")
        toKeep = ["start", "end", 'F0semitoneFrom27.5Hz_sma3nz', 'F1frequency_sma3nz', 'mfcc1_sma3', 'mfcc2_sma3', 'mfcc3_sma3','mfcc4_sma3']
        # prosodyDf = pd.read_csv(prosody_file, usecols=toKeep)
        prosodyDf = prosodydf.reset_index()[toKeep]

        # Apply the microsecond fix to the 'start' and 'end' columns
        prosodyDf["start"] = prosodyDf["start"].astype(str)
        prosodyDf["end"] = prosodyDf["end"].astype(str)
        prosodyDf["start"] = prosodyDf["start"].apply(addMicroseconds)
        prosodyDf["end"] = prosodyDf["end"].apply(addMicroseconds)

        # Extract just the time (ignoring the date) and convert it to datetime format
        prosodyDf["start"] = prosodyDf["start"].apply(lambda x: x.split(" ")[2])
        prosodyDf["start"] = pd.to_datetime(prosodyDf["start"], format="%H:%M:%S.%f")
        prosodyDf["end"] = prosodyDf["end"].apply(lambda x: x.split(" ")[2])
        prosodyDf["end"] = pd.to_datetime(prosodyDf["end"], format="%H:%M:%S.%f")

        # Convert the 'start' and 'end' times into seconds relative to the first start time
        prosodyDf["end"] = (prosodyDf["end"] - prosodyDf.loc[0, "start"]).dt.total_seconds()
        prosodyDf["start"] = (prosodyDf["start"] - prosodyDf.loc[0, "start"]).dt.total_seconds()

        # Keep every second row (removing overlapping time chunks to avoid redundancy)
        prosodyDf = prosodyDf[prosodyDf.index % 2 == 0].reset_index(drop=True)

        # Read the transcript file
        toKeep2 = ["start", "end", "content"]
        # transcriptDF = pd.read_csv(transcript_file, usecols=['Begin', 'End', 'Label'])
        transcriptDf = transcriptdf[transcriptdf['Type'] == 'words']
        transcriptDf = transcriptDf.rename(columns={'Begin': 'start', 'End': 'end', 'Label': 'content'})

        # Reset the index to clean the DataFrame
        transcriptDf = transcriptDf.reset_index()

        # Display the first few rows of the transcript DataFrame
        transcriptDf.head(4)

        # Convert the prosody DataFrame into a list for easier processing
        prosList = prosodyDf.values.tolist()

        # Initialize lists to store average and individual prosody values
        allProsAvgs = []
        allProsVals = []

        # Initialize the prosody index for looping through prosody data
        prosIndex = 0
        prosStart = prosList[prosIndex][0]  # Start time of the first prosody chunk
        prosEnd = prosList[prosIndex][1]    # End time of the first prosody chunk
        prosMid = (prosStart + prosEnd) / 2.0  # Midpoint of the prosody chunk
        prosVals = prosList[prosIndex][2:]  # Prosody feature values for this chunk

        # Loop through each token (subtitle segment) in the transcript
        for tokIndex, tokStart, tokEnd in transcriptDf[["index", "start", "end"]].values.tolist(): 

            # Initialize an empty list to store prosody values for the current token
            currProsVals = [[] for i in range(len(prosVals))]

            # Add prosody values as long as the midpoint of the prosody chunk is within the current token's time range
            while prosMid < tokEnd:

                # For each prosody value, append it to the corresponding list
                for i, prosVal in enumerate(prosVals): 
                    currProsVals[i].append(prosVal)

                prosIndex += 1  # Move to the next prosody chunk

                # Break the loop if we've processed all the prosody data
                if prosIndex >= len(prosList): 
                    break

                # Update prosody start, end, and mid times for the new chunk
                prosStart = prosList[prosIndex][0]
                prosEnd = prosList[prosIndex][1]
                prosMid = (prosStart + prosEnd) / 2.0
                prosVals = prosList[prosIndex][2:]

            # Add the prosody values for the current token to the list
            allProsVals.append(currProsVals)


        # Convert the list of prosody values into a DataFrame
        prosodyGrouped = pd.DataFrame(allProsVals, columns=list(prosodyDf.columns)[2:])

        # Define a function to calculate the slope of the regression line for a list of values
        lr = LinearRegression(fit_intercept=True)

        # Suppress warnings for empty lists during mean/median calculations and apply the functions
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", category=RuntimeWarning)
            prosodyAvgd = prosodyGrouped.applymap(np.mean)  # Calculate mean prosody values
            prosodyMedianed = prosodyGrouped.applymap(np.median)  # Calculate median prosody values
            prosodySlopes = prosodyGrouped.applymap(getSlope)  # Calculate slope (rate of change)

        # Add the average prosody values to the transcript DataFrame
        transcriptDf[list(prosodyDf.columns)[2:]] = prosodyAvgd

        # Add the slope values (rate of change) to the transcript DataFrame
        transcriptDf[[item + "Slope" for item in list(prosodyDf.columns)[2:]]] = prosodySlopes

        # Occasionally, transcript tokens may have zero time duration, leading to missing prosody values
        # We use forward fill to replace these missing values with the previous row's values
        transcriptDf = transcriptDf.fillna(method="ffill")
        
        # Save the resulting DataFrame
        output_path = os.path.join(output_directory, f"{file_index}-{name}.csv")
        transcriptDf.to_csv(output_path, index=False)
        print(f"Saved merged file: {output_path}")
        
    except Exception as e:
        print(f"Error merging files for {file_index}-{name}: {e}")

# %%
def determine_num_processors(specified_processors=None):
    # If specified_processors is provided, use it; otherwise, use the CPU count
    return specified_processors if specified_processors else multiprocessing.cpu_count()

# %%
metadata_path = "/shared/3/projects/benlitterer/podcastData/processed/mayJune/mayJuneDataClean.jsonl"
download_directory = "/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/"
output_directory = "/shared/3/projects/bangzhao/prosodic_embeddings/merge/output/"
transcript_path = '/shared/3/projects/bangzhao/prosodic_embeddings/mfa/output/'

# %%
from concurrent.futures import ProcessPoolExecutor, as_completed

def process_file(i, filename, transcript_path, metadata_path, download_directory, output_directory):
    # Check if the filename is a CSV file
    if not filename.endswith(".csv"):
        return
    
    # Get the metadata
    line = int(filename.split('-')[0]) + 1
    metadata = read_nth_line_as_json(metadata_path, line)
    
    # Get the standardized name
    new_name = standardize_name(metadata['enclosure'])
    
    # Download MP3 from URL and convert to WAV
    wav_file_path = os.path.join(download_directory, new_name + '.wav')
    download_and_convert(metadata, new_name, download_directory)
    
    # Get prosody
    prosodydf = extract_prosody(wav_file_path, os.path.join(download_directory, new_name))
    
    # Read transcript
    file_path = os.path.join(transcript_path, filename)
    transcriptdf = pd.read_csv(file_path)
    
    # Merge prosody and transcript
    merge_prosody_transcript(prosodydf, transcriptdf, new_name, i, output_directory)
    
    # Remove the WAV file after merging
    if os.path.exists(wav_file_path):
        os.remove(wav_file_path)

def main(transcript_path, metadata_path, download_directory, output_directory):
    # List all CSV files in the directory, starting from the 3000th file
    files = [f for f in os.listdir(transcript_path) if f.endswith('.csv')][3014:]

    # Set up the ProcessPoolExecutor with 12 workers
    with ProcessPoolExecutor(max_workers=12) as executor:
        # Submit each file for processing
        futures = {
            executor.submit(
                process_file, i + 3014, filename, transcript_path, metadata_path, download_directory, output_directory
            ): filename for i, filename in enumerate(files)
        }

        # Collect results as they complete
        for future in as_completed(futures):
            filename = futures[future]
            try:
                future.result()  # If there's an exception, it will be raised here
                print(f"Processing completed for: {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {e}")

# %%
main(transcript_path, metadata_path, download_directory, output_directory)
# Out:
# Processing: httpsanchor.fms23ca2d94podcastplay15431745https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F2a7f99ab6d841cb7ab13b9a3f8c9b31f.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3023-httpsanchor.fms23ca2d94podcastplay15431745https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F2a7f99ab6d841cb7ab13b9a3f8c9b31f.m4a.csv
# Processing completed for: 6629-httpsanchor.fms23ca2d94podcastplay15431745httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-192a7f99ab6d841cb7ab13b9a3f8c9b31f.m4.csv
# Processing: httpstraffic.megaphone.fmAPO1228945082.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3021-httpstraffic.megaphone.fmAPO1228945082.mp3.csv
# Processing completed for: 6668-httpstraffic.megaphone.fmAPO1228945082.mp3.csv
# Processing: httpsanchor.fms122547ccpodcastplay13986932https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204192F74699944441002ff8491b2f9c48.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3027-httpsanchor.fms122547ccpodcastplay13986932https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204192F74699944441002ff8491b2f9c48.mp3.csv
# Processing completed for: 6651-httpsanchor.fms122547ccpodcastplay13986932httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-4-1974699944-44100-2-ff8491b2f9c48.mp.csv
# Processing: httpsanchor.fmsbd52810podcastplay15168463https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205142F821626114410028b3090a36b2b2.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3017-httpsanchor.fmsbd52810podcastplay15168463https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205142F821626114410028b3090a36b2b2.mp3.csv
# Processing completed for: 6476-httpsanchor.fmsbd52810podcastplay15168463httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-1482162611-44100-2-8b3090a36b2b2.mp3.csv
# Processing: httpsanchor.fmsbe95420podcastplay13216088https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202005022F2951580368d5a60242620ef87401dc8d.m4a
# Processing: httpsfeeds.soundcloud.comstream837071026user62053836301152020wednesdaypastormundayacts28.mp3
# Processing: httpsanchor.fms102b0da8podcastplay15172151https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006222Fa78dce73386b7973a859981217814f0e.m4a
# Processing: httpsfeeds.soundcloud.comstream837072442user62053836301222020wednesdaypastormundayacts28.mp3
# Processing: httpstraffic.megaphone.fmAPO4320770439.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3022-httpsanchor.fmsbe95420podcastplay13216088https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202005022F2951580368d5a60242620ef87401dc8d.m4a.csv
# Processing completed for: 6628-httpsanchor.fmsbe95420podcastplay13216088httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-05-022951580368d5a60242620ef87401dc8d.m4a.csv
# Processing: httpsanchor.fmsbd52810podcastplay14988774https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205102F810588084410022a9f02744f7e5.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3024-httpsfeeds.soundcloud.comstream837071026user62053836301152020wednesdaypastormundayacts28.mp3.csv
# Processing completed for: 6659-httpsfeeds.soundcloud.comstream837071026-user-620538363-01152020-wednesday-pastor-munday-acts-28.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3026-httpsfeeds.soundcloud.comstream837072442user62053836301222020wednesdaypastormundayacts28.mp3.csv
# Processing completed for: 6657-httpsfeeds.soundcloud.comstream837072442-user-620538363-01222020-wednesday-pastor-munday-acts-28.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3014-httpsanchor.fms102b0da8podcastplay15172151https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006222Fa78dce73386b7973a859981217814f0e.m4a.csv
# Processing completed for: 6433-httpsanchor.fms102b0da8podcastplay15172151httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-22a78dce73386b7973a859981217814f0e.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3025-httpstraffic.megaphone.fmAPO4320770439.mp3.csv
# Processing completed for: 6644-httpstraffic.megaphone.fmAPO4320770439.mp3.csv
# Processing: httpsanchor.fms23ca2d94podcastplay15104784https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F075d2a7fc3bbb563aabf6c9930cc28e2.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3018-httpsanchor.fmsbd52810podcastplay14988774https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205102F810588084410022a9f02744f7e5.mp3.csv
# Processing completed for: 6478-httpsanchor.fmsbd52810podcastplay14988774httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-1081058808-44100-2-2a9f02744f7e5.mp3.csv
# Processing: httpsanchor.fms23ca2d94podcastplay14470256https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F4e6664b18783a98d671949f12446ff28.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3031-httpsanchor.fms23ca2d94podcastplay15104784https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F075d2a7fc3bbb563aabf6c9930cc28e2.m4a.csv
# Processing completed for: 6630-httpsanchor.fms23ca2d94podcastplay15104784httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-19075d2a7fc3bbb563aabf6c9930cc28e2.m4.csv
# Processing: httpsanchor.fms102b0da8podcastplay14554182https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202005312Fbb5098db7154047e0ab4621ba6c5e3e1.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3032-httpsanchor.fms23ca2d94podcastplay14470256https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F4e6664b18783a98d671949f12446ff28.m4a.csv
# Processing completed for: 6634-httpsanchor.fms23ca2d94podcastplay14470256httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-194e6664b18783a98d671949f12446ff28.m4.csv
# Processing: httpschtbl.comtrackGAFB26cdn.simplecast.comaudioe7abd6e7abd60955144fedad826fa47cdcbeaf5bf474b1bb614f5a80601822e9e40919patriciaduchenepodcastoutput_tc.mp3aidrss_feedfeedSEn2zacv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3020-httpsanchor.fms102b0da8podcastplay14554182https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202005312Fbb5098db7154047e0ab4621ba6c5e3e1.m4a.csv
# Processing completed for: 6435-httpsanchor.fms102b0da8podcastplay14554182httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-05-31bb5098db7154047e0ab4621ba6c5e3e1.m4.csv
# Processing: httpdts.podtrac.comredirect.mp3static1.squarespace.comstatic5d0710c75ae6fa0001db3f17t5eb5a79a8622770ac8055f001592221282068SH21ExtraCurriculars_mixdown.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3019-httpschtbl.comtrackGAFB26cdn.simplecast.comaudioe7abd6e7abd60955144fedad826fa47cdcbeaf5bf474b1bb614f5a80601822e9e40919patriciaduchenepodcastoutput_tc.mp3aidrss_feedfeedSEn2zacv.csv
# Processing completed for: 6438-httpschtbl.comtrackGAFB26cdn.simplecast.comaudioe7abd6e7abd609-5514-4fed-ad82-6fa47cdcbeaf5bf474b1-bb61-4f5a-8060-1822e9e40919pa.csv
# Processing: httpsfeeds.soundcloud.comstream837066871user62053836301052020sundaypmpastorwesjude.mp3
# Processing: httpsanchor.fmsbe95420podcastplay15554694https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006242Fb16b4781ea5be8b3a4d4a84c8ce5afae.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3016-httpdts.podtrac.comredirect.mp3static1.squarespace.comstatic5d0710c75ae6fa0001db3f17t5eb5a79a8622770ac8055f001592221282068SH21ExtraCurriculars_mixdown.mp3.csv
# Processing completed for: 6443-httpdts.podtrac.comredirect.mp3static1.squarespace.comstatic5d0710c75ae6fa0001db3f17t5eb5a79a8622770ac8055f001592221282068SH21+-.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3033-httpsanchor.fmsbe95420podcastplay15554694https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006242Fb16b4781ea5be8b3a4d4a84c8ce5afae.m4a.csv
# Processing completed for: 6624-httpsanchor.fmsbe95420podcastplay15554694httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-24b16b4781ea5be8b3a4d4a84c8ce5afae.m4a.csv
# Processing: httpdts.podtrac.comredirect.mp3static1.squarespace.comstatic5d0710c75ae6fa0001db3f17t5eac38d8df99770838d6d01d1589733510582SH20Sleep_mixdown.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3028-httpsfeeds.soundcloud.comstream837066871user62053836301052020sundaypmpastorwesjude.mp3.csv
# Processing completed for: 6661-httpsfeeds.soundcloud.comstream837066871-user-620538363-01052020-sunday-pm-pastor-wes-jude.mp3.csv
# Processing: httpsanchor.fms23ca2d94podcastplay14616917https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F9170bf1c4ce7ab243028cbb8880e0e25.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3040-httpsanchor.fms23ca2d94podcastplay14616917https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F9170bf1c4ce7ab243028cbb8880e0e25.m4a.csv
# Processing completed for: 6631-httpsanchor.fms23ca2d94podcastplay14616917httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-199170bf1c4ce7ab243028cbb8880e0e25.m4.csv
# Processing: httpsanchor.fmsbe95420podcastplay13668814https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202005152F3c7840c2e3c38db2128eb8e35437ecd8.m4a
# Processing: httpsanchor.fmsbe95420podcastplay14821429https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006062Fcd674fa48ecf54893739aad0766efa35.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3039-httpsanchor.fmsbe95420podcastplay13668814https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202005152F3c7840c2e3c38db2128eb8e35437ecd8.m4a.csv
# Processing completed for: 6627-httpsanchor.fmsbe95420podcastplay13668814httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-05-153c7840c2e3c38db2128eb8e35437ecd8.m4a.csv
# Processing: httpsanchor.fms23ca2d94podcastplay14463277https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F0382e46496296e654529325158119c1c.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3042-httpsanchor.fms23ca2d94podcastplay14463277https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F0382e46496296e654529325158119c1c.m4a.csv
# Processing completed for: 6635-httpsanchor.fms23ca2d94podcastplay14463277httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-190382e46496296e654529325158119c1c.m4.csv
# Processing: httpsfeeds.soundcloud.comstream837074905user62053836301292020wednesdaypastormundayobadiah.mp3
# Processing: httpsanchor.fms23ca2d94podcastplay14471064https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F3c0b216fc54bd25be14eb298d39c65c3.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3045-httpsanchor.fms23ca2d94podcastplay14471064https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006192F3c0b216fc54bd25be14eb298d39c65c3.m4a.csv
# Processing completed for: 6633-httpsanchor.fms23ca2d94podcastplay14471064httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-193c0b216fc54bd25be14eb298d39c65c3.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3037-httpsanchor.fmsbe95420podcastplay14821429https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006062Fcd674fa48ecf54893739aad0766efa35.m4a.csv
# Processing completed for: 6626-httpsanchor.fmsbe95420podcastplay14821429httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-06cd674fa48ecf54893739aad0766efa35.m4a.csv
# Processing: httpsfeeds.soundcloud.comstream837071764user62053836301192020sundaypmfrankcamp10thingsfamily.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3015-httpdts.podtrac.comredirect.mp3static1.squarespace.comstatic5d0710c75ae6fa0001db3f17t5eac38d8df99770838d6d01d1589733510582SH20Sleep_mixdown.mp3.csv
# Processing completed for: 6444-httpdts.podtrac.comredirect.mp3static1.squarespace.comstatic5d0710c75ae6fa0001db3f17t5eac38d8df99770838d6d01d1589733510582SH20+-.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3036-httpsfeeds.soundcloud.comstream837074905user62053836301292020wednesdaypastormundayobadiah.mp3.csv
# Processing completed for: 6655-httpsfeeds.soundcloud.comstream837074905-user-620538363-01292020-wednesday-pastor-munday-obadiah.mp3.csv
# Processing: httpstraffic.megaphone.fmAPO4675056061.mp3
# Processing: httpsfeeds.soundcloud.comstream837063409user62053836312152019sundaypmpastormundaylifeofdavidproverbs1315.mp3
# Processing: httpsanchor.fms23ca2d94podcastplay14471917https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006012F9e5f07383065498f9d91222cc390afd6.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3047-httpsanchor.fms23ca2d94podcastplay14471917https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006012F9e5f07383065498f9d91222cc390afd6.m4a.csv
# Processing completed for: 6632-httpsanchor.fms23ca2d94podcastplay14471917httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-019e5f07383065498f9d91222cc390afd6.m4.csv
# Processing: httpsfeeds.soundcloud.comstream837064552user62053836312292019sundaypmpastormundaylifeofdavid.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3041-httpstraffic.megaphone.fmAPO4675056061.mp3.csv
# Processing completed for: 6670-httpstraffic.megaphone.fmAPO4675056061.mp3.csv
# Processing: httpsfeeds.soundcloud.comstream837064165user62053836312292019sundayamthaynemundaymatthew633.mp3
# Processing: httpsanchor.fms23ca2d94podcastplay14461584https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204292F77753856480002d968a7501afd3.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3051-httpsanchor.fms23ca2d94podcastplay14461584https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204292F77753856480002d968a7501afd3.mp3.csv
# Processing completed for: 6636-httpsanchor.fms23ca2d94podcastplay14461584httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-4-2977753856-48000-2-d968a7501afd3.mp.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3029-httpsfeeds.soundcloud.comstream837071764user62053836301192020sundaypmfrankcamp10thingsfamily.mp3.csv
# Processing completed for: 6658-httpsfeeds.soundcloud.comstream837071764-user-620538363-01192020-sunday-pm-frank-camp-10-things-family.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3034-httpsfeeds.soundcloud.comstream837063409user62053836312152019sundaypmpastormundaylifeofdavidproverbs1315.mp3.csv
# Processing completed for: 6667-httpsfeeds.soundcloud.comstream837063409-user-620538363-12152019-sunday-pm-pastor-munday-life-of-david-proverbs-13-15.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3038-httpsfeeds.soundcloud.comstream837064552user62053836312292019sundaypmpastormundaylifeofdavid.mp3.csv
# Processing completed for: 6664-httpsfeeds.soundcloud.comstream837064552-user-620538363-12292019-sunday-pm-pastor-munday-life-of-david.mp3.csv
# Processing: httpsanchor.fms18bfaa14podcastplay15166902https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205142F821544784410012fd58b9062595.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3054-httpsanchor.fms18bfaa14podcastplay15166902https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205142F821544784410012fd58b9062595.m4a.csv
# Processing completed for: 6809-httpsanchor.fms18bfaa14podcastplay15166902httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-1482154478-44100-1-2fd58b9062595.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3035-httpsfeeds.soundcloud.comstream837064165user62053836312292019sundayamthaynemundaymatthew633.mp3.csv
# Processing completed for: 6665-httpsfeeds.soundcloud.comstream837064165-user-620538363-12292019-sunday-am-thayne-munday-matthew-6-33.mp3.csv
# Processing: httpsanchor.fms18bfaa14podcastplay15511752https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F5d696527a7b3970d32e09d49d3bec47e.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3055-httpsanchor.fms18bfaa14podcastplay15511752https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F5d696527a7b3970d32e09d49d3bec47e.m4a.csv
# Processing completed for: 6808-httpsanchor.fms18bfaa14podcastplay15511752httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-205d696527a7b3970d32e09d49d3bec47e.m4.csv
# Processing: httpsanchor.fms18bfaa14podcastplay15598041https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F940a97fa9013e64315586e028788c796.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3056-httpsanchor.fms18bfaa14podcastplay15598041https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F940a97fa9013e64315586e028788c796.m4a.csv
# Processing completed for: 6806-httpsanchor.fms18bfaa14podcastplay15598041httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-20940a97fa9013e64315586e028788c796.m4.csv
# Processing: httpsanchor.fms122547ccpodcastplay12856119https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20203242F67250486441002d8c357bd841d8.mp3
# Processing: httpsfeeds.soundcloud.comstream837070717user62053836301122020sundayampastormundaythemesunday2corinthians1.mp3
# Processing: httpsanchor.fmsbe95420podcastplay15149223https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006132Ff327e91ae441a268e14ab96a84dc91f0.m4a
# Processing: httpstraffic.megaphone.fmAPO6213842893.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3048-httpsanchor.fms122547ccpodcastplay12856119https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20203242F67250486441002d8c357bd841d8.mp3.csv
# Processing completed for: 6653-httpsanchor.fms122547ccpodcastplay12856119httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-3-2467250486-44100-2-d8c357bd841d8.mp.csv
# Processing: httpsfeeds.soundcloud.comstream837065107user62053836301022020thursdaypastormundaybiblicalcivicduty.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3052-httpstraffic.megaphone.fmAPO6213842893.mp3.csv
# Processing completed for: 6669-httpstraffic.megaphone.fmAPO6213842893.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3044-httpsanchor.fmsbe95420podcastplay15149223https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006132Ff327e91ae441a268e14ab96a84dc91f0.m4a.csv
# Processing completed for: 6625-httpsanchor.fmsbe95420podcastplay15149223httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-13f327e91ae441a268e14ab96a84dc91f0.m4a.csv
# Processing: httpsanchor.fms18bfaa14podcastplay15064664https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fa1b66c96401bbad2e52ecf54562b1ca4.m4a
# Processing: httpsanchor.fms18bfaa14podcastplay15090544https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F8d51e3c05f5cd4f0dc5da68a89454f49.m4a
# Processing: httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzNlNWFkZWM4LTc3ZDItNDlkMy05NDYzLTM5NjRkN2U1ZmMxZS9hdWRpby5tcDM.mp3kQZJ6W4s3sapidfypwysw
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3059-httpsanchor.fms18bfaa14podcastplay15064664https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fa1b66c96401bbad2e52ecf54562b1ca4.m4a.csv
# Processing completed for: 6811-httpsanchor.fms18bfaa14podcastplay15064664httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-20a1b66c96401bbad2e52ecf54562b1ca4.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3058-httpsanchor.fms18bfaa14podcastplay15090544https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F8d51e3c05f5cd4f0dc5da68a89454f49.m4a.csv
# Processing completed for: 6810-httpsanchor.fms18bfaa14podcastplay15090544httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-208d51e3c05f5cd4f0dc5da68a89454f49.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3057-httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzNlNWFkZWM4LTc3ZDItNDlkMy05NDYzLTM5NjRkN2U1ZmMxZS9hdWRpby5tcDM.mp3kQZJ6W4s3sapidfypwysw.csv
# Processing completed for: 6797-httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzNlNWFkZWM4LTc3ZDItNDlkMy05NDYzLTM5NjRkN2U1ZmMxZS9hdWR.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3043-httpsfeeds.soundcloud.comstream837065107user62053836301022020thursdaypastormundaybiblicalcivicduty.mp3.csv
# Processing completed for: 6663-httpsfeeds.soundcloud.comstream837065107-user-620538363-01022020-thursday-pastor-munday-biblical-civic-duty.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3030-httpsfeeds.soundcloud.comstream837070717user62053836301122020sundayampastormundaythemesunday2corinthians1.mp3.csv
# Processing completed for: 6660-httpsfeeds.soundcloud.comstream837070717-user-620538363-01122020-sunday-am-pastor-munday-theme-sunday-2-corinthians-1.mp3.csv
# Processing: httpsanchor.fms18bfaa14podcastplay15789543https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F32f0da981e679032532320ad56e81069.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3064-httpsanchor.fms18bfaa14podcastplay15789543https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F32f0da981e679032532320ad56e81069.m4a.csv
# Processing completed for: 6803-httpsanchor.fms18bfaa14podcastplay15789543httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-2032f0da981e679032532320ad56e81069.m4.csv
# Processing: httpsfeeds.soundcloud.comstream837074392user62053836301262020sundayampastormunday.mp3
# Processing: httpsanchor.fms18bfaa14podcastplay15549569https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fb56d37537f7b92bc1585682969cb6f76.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3065-httpsanchor.fms18bfaa14podcastplay15549569https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fb56d37537f7b92bc1585682969cb6f76.m4a.csv
# Processing completed for: 6807-httpsanchor.fms18bfaa14podcastplay15549569httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-20b56d37537f7b92bc1585682969cb6f76.m4.csv
# Processing: httpsanchor.fms18bfaa14podcastplay14855009https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fc846c99b5cfeaa8f0a72c2ad4d3bf21f.m4a
# Processing: httpsanchor.fms18bfaa14podcastplay14951547https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fe57cd9f88050d5676fa1d86da3344a5d.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3066-httpsanchor.fms18bfaa14podcastplay14855009https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fc846c99b5cfeaa8f0a72c2ad4d3bf21f.m4a.csv
# Processing completed for: 6814-httpsanchor.fms18bfaa14podcastplay14855009httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-20c846c99b5cfeaa8f0a72c2ad4d3bf21f.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3046-httpsfeeds.soundcloud.comstream837074392user62053836301262020sundayampastormunday.mp3.csv
# Processing completed for: 6656-httpsfeeds.soundcloud.comstream837074392-user-620538363-01262020-sunday-am-pastor-munday.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3062-httpsanchor.fms18bfaa14podcastplay14951547https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fe57cd9f88050d5676fa1d86da3344a5d.m4a.csv
# Processing completed for: 6813-httpsanchor.fms18bfaa14podcastplay14951547httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-20e57cd9f88050d5676fa1d86da3344a5d.m4.csv
# Processing: httpspdcn.coemcdn.podbean.commfwebkct0qjKellyMartinSpeaksEpisode97ACrisisIsanOpportunityai30c.mp3
# Processing: httpsanchor.fms18bfaa14podcastplay14818387https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F1a57bf2eb163a58f00b845b90025694e.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3071-httpsanchor.fms18bfaa14podcastplay14818387https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F1a57bf2eb163a58f00b845b90025694e.m4a.csv
# Processing completed for: 6815-httpsanchor.fms18bfaa14podcastplay14818387httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-201a57bf2eb163a58f00b845b90025694e.m4.csv
# Processing: httpsanchor.fms18bfaa14podcastplay15746815https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fdc9a7b6b6ac87b42a3de5595ec67dc80.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3061-httpspdcn.coemcdn.podbean.commfwebkct0qjKellyMartinSpeaksEpisode97ACrisisIsanOpportunityai30c.mp3.csv
# Processing completed for: 7375-httpspdcn.coemcdn.podbean.commfwebkct0qjKellyMartinSpeaksEpisode97ACrisisIsanOpportunityai30c.mp3.csv
# Processing: httpsfeeds.soundcloud.comstream837063853user62053836312182019wednesdaypastormundayacts25.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3063-httpsanchor.fms18bfaa14podcastplay15746815https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202Fdc9a7b6b6ac87b42a3de5595ec67dc80.m4a.csv
# Processing completed for: 6804-httpsanchor.fms18bfaa14podcastplay15746815httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-20dc9a7b6b6ac87b42a3de5595ec67dc80.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3053-httpsfeeds.soundcloud.comstream837063853user62053836312182019wednesdaypastormundayacts25.mp3.csv
# Processing completed for: 6666-httpsfeeds.soundcloud.comstream837063853-user-620538363-12182019-wednesday-pastor-munday-acts-25.mp3.csv
# Processing: httpwww.podtrac.comptsredirect.mp3feeds.soundcloud.comstream814892992electranassoctransactconnectwhattoexpect.mp3
# Processing: httpsfeeds.soundcloud.comstream837066049user62053836301052020sundayampastormundaythattheearthmayknow.mp3
# Processing: httpsfeeds.soundcloud.comstream837075367user62053836302022020sundayampastormundayastrategytohelpothers.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3068-httpwww.podtrac.comptsredirect.mp3feeds.soundcloud.comstream814892992electranassoctransactconnectwhattoexpect.mp3.csv
# Processing completed for: 6792-httpwww.podtrac.comptsredirect.mp3feeds.soundcloud.comstream814892992-elec-tran-assoc-transact-connect-what-to-expect.mp3.csv
# Processing: httpsmcdn.podbean.commfwebfh4abnKateEp15racism.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3075-httpsmcdn.podbean.commfwebfh4abnKateEp15racism.mp3.csv
# Processing completed for: 6406-httpsmcdn.podbean.commfwebfh4abnKateEp15-racism.mp3.csv
# Processing: httpsfeeds.soundcloud.comstream827942701wrolbroadcastlootisfinallyoverhisparasitedclegendsmobile.mp3
# Processing: httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzE2YWU4ZWU4LTU2ZGEtNDk5Zi1iNWU1LTdmZTI5ODJkNWEzYS9hdWRpby5tNGE.m4akQZJ6W4s3sapidb54wwvd
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3073-httpsfeeds.soundcloud.comstream827942701wrolbroadcastlootisfinallyoverhisparasitedclegendsmobile.mp3.csv
# Processing completed for: 6787-httpsfeeds.soundcloud.comstream827942701-wrolbroadcast-loot-is-finally-over-his-parasite-dc-legends-mobile.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3050-httpsfeeds.soundcloud.comstream837066049user62053836301052020sundayampastormundaythattheearthmayknow.mp3.csv
# Processing completed for: 6662-httpsfeeds.soundcloud.comstream837066049-user-620538363-01052020-sunday-am-pastor-munday-that-the-earth-may-know.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3060-httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzE2YWU4ZWU4LTU2ZGEtNDk5Zi1iNWU1LTdmZTI5ODJkNWEzYS9hdWRpby5tNGE.m4akQZJ6W4s3sapidb54wwvd.csv
# Processing completed for: 6801-httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzE2YWU4ZWU4LTU2ZGEtNDk5Zi1iNWU1LTdmZTI5ODJkNWEzYS9hdWR.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3049-httpsfeeds.soundcloud.comstream837075367user62053836302022020sundayampastormundayastrategytohelpothers.mp3.csv
# Processing completed for: 6654-httpsfeeds.soundcloud.comstream837075367-user-620538363-02022020-sunday-am-pastor-munday-a-strategy-to-help-others.mp3.csv
# Processing: httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzRjY2NiYzJkLTRhOGMtNGUzZi05NWY3LWU1M2Y5NGJlOTZlOS9hdWRpby5tcDM.mp3kQZJ6W4s3sapidj9zmf7c
# Processing: httpsmcdn.podbean.commfwebc37e7tKateEp16whatnext.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3069-httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzRjY2NiYzJkLTRhOGMtNGUzZi05NWY3LWU1M2Y5NGJlOTZlOS9hdWRpby5tcDM.mp3kQZJ6W4s3sapidj9zmf7c.csv
# Processing completed for: 6793-httpst.subsplash.comraHR0cHM6Ly9jZG4uc3Vic3BsYXNoLmNvbS9hdWRpb3MvUVpKNlc0LzRjY2NiYzJkLTRhOGMtNGUzZi05NWY3LWU1M2Y5NGJlOTZlOS9hdWR.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3079-httpsmcdn.podbean.commfwebc37e7tKateEp16whatnext.mp3.csv
# Processing completed for: 6405-httpsmcdn.podbean.commfwebc37e7tKateEp16-whatnext.mp3.csv
# Processing: httpsfeeds.soundcloud.comstream835498849rcpsychcpdonlineworkingwithpatientsremotely.mp3
# Processing: httpsanchor.fms2e00edcpodcastplay13498576https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F2020492F7150991644100291658bf63c663.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3076-httpsfeeds.soundcloud.comstream835498849rcpsychcpdonlineworkingwithpatientsremotely.mp3.csv
# Processing completed for: 6401-httpsfeeds.soundcloud.comstream835498849-rcpsych-cpdonline-working-with-patients-remotely.mp3.csv
# Processing: httpsmcdn.podbean.commfweb5ur7t5KateEp10veenu.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3070-httpsanchor.fms2e00edcpodcastplay13498576https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F2020492F7150991644100291658bf63c663.m4a.csv
# Processing completed for: 6768-httpsanchor.fms2e00edcpodcastplay13498576httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-4-971509916-44100-2-91658bf63c663.m4a.csv
# Processing: httpsstatic1.squarespace.comstatic5ce01548eef63e0001b0254dt5ec469ddd85b641a7690b1411590617422612Louie1.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3077-httpsmcdn.podbean.commfweb5ur7t5KateEp10veenu.mp3.csv
# Processing completed for: 6411-httpsmcdn.podbean.commfweb5ur7t5KateEp10-veenu.mp3.csv
# Processing: httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333811115marketingwithpurposenatalieriviere.mp33Fblob_id3D14442545
# Processing: httpsfeeds.soundcloud.comstream835488460rcpsychcpdonlinehowdoweleadeffectivelythroughthecovid19pandemic.mp3
# Processing: httpsmcdn.podbean.commfwebr7afg1KateEp13The_5_Biggest_Mistakes_I_ve_Made_as_an_Entrepreneur_and_Why_They_Were_All_Worth_It_bi0pr.mp3
# Processing: httpsfeeds.soundcloud.comstream812932033wrolbroadcastgorillakhoddcast17may03.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3072-httpsstatic1.squarespace.comstatic5ce01548eef63e0001b0254dt5ec469ddd85b641a7690b1411590617422612Louie1.mp3.csv
# Processing completed for: 6772-httpsstatic1.squarespace.comstatic5ce01548eef63e0001b0254dt5ec469ddd85b641a7690b1411590617422612Louie+1.mp3.csv
# Processing: httpsmcdn.podbean.commfwebhdr0ldKateEp11reset.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3084-httpsmcdn.podbean.commfwebr7afg1KateEp13The_5_Biggest_Mistakes_I_ve_Made_as_an_Entrepreneur_and_Why_They_Were_All_Worth_It_bi0pr.mp3.csv
# Processing completed for: 6408-httpsmcdn.podbean.commfwebr7afg1KateEp13-The_5_Biggest_Mistakes_I_ve_Made_as_an_Entrepreneur_and_Why_They_Were_All_Worth_It_bi0p.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3085-httpsmcdn.podbean.commfwebhdr0ldKateEp11reset.mp3.csv
# Processing completed for: 6410-httpsmcdn.podbean.commfwebhdr0ldKateEp11-reset.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3078-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333811115marketingwithpurposenatalieriviere.mp33Fblob_id3D14442545.csv
# Processing completed for: 6389-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53-360439333811115-marketing-with-purpose-natalie-riviere.mp3blob_id=144.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3080-httpsfeeds.soundcloud.comstream835488460rcpsychcpdonlinehowdoweleadeffectivelythroughthecovid19pandemic.mp3.csv
# Processing completed for: 6400-httpsfeeds.soundcloud.comstream835488460-rcpsych-cpdonline-how-do-we-lead-effectively-through-the-covid-19-pandemic.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3067-httpsfeeds.soundcloud.comstream812932033wrolbroadcastgorillakhoddcast17may03.mp3.csv
# Processing completed for: 6791-httpsfeeds.soundcloud.comstream812932033-wrolbroadcast-gorilla-khodd-cast-17-may-03.mp3.csv
# Processing: httpsfeeds.soundcloud.comstream835524868rcpsychcpdonlineethicalconsiderationsarisingfromcovid19.mp3
# Processing: httpsfeeds.soundcloud.comstream940675354rcpsychcpdonlineobediencetoauthoritylessonsfrommilgramappliedtocovid19.mp3
# Processing: httpsmcdn.podbean.commfwebnkop3xKateEp12cancer.mp3
# Processing: httpsfeeds.soundcloud.comstream829252915resurgentupodcastepisode17leadershipstrength.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3088-httpsmcdn.podbean.commfwebnkop3xKateEp12cancer.mp3.csv
# Processing completed for: 6409-httpsmcdn.podbean.commfwebnkop3xKateEp12-cancer.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3087-httpsfeeds.soundcloud.comstream835524868rcpsychcpdonlineethicalconsiderationsarisingfromcovid19.mp3.csv
# Processing completed for: 6402-httpsfeeds.soundcloud.comstream835524868-rcpsych-cpdonline-ethical-considerations-arising-from-covid-19.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3091-httpsfeeds.soundcloud.comstream829252915resurgentupodcastepisode17leadershipstrength.mp3.csv
# Processing completed for: 6425-httpsfeeds.soundcloud.comstream829252915-resurgentupodcast-episode-17-leadership-strength.mp3.csv
# Processing: httpsfeeds.soundcloud.comstream835434301rcpsychcpdonlinementalhealthtribunalsresponsetothecovid19emergency.mp3
# Processing: httpsmcdn.podbean.commfweby5h3m5KateEp18takecare.mp3
# Processing: httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439334190633connectingthedotswithfranksonder.mp33Fblob_id3D16400096
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3092-httpsmcdn.podbean.commfweby5h3m5KateEp18takecare.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3086-httpsfeeds.soundcloud.comstream940675354rcpsychcpdonlineobediencetoauthoritylessonsfrommilgramappliedtocovid19.mp3.csv
# Processing completed for: 6404-httpsmcdn.podbean.commfweby5h3m5KateEp18-takecare.mp3.csv
# Processing completed for: 6398-httpsfeeds.soundcloud.comstream940675354-rcpsych-cpdonline-obedience-to-authority-lessons-from-milgram-applied-to-covid-19.mp3.csv
# Processing: httpsfeeds.soundcloud.comstream822605398rcpsychcpdonlinecovid19isolationandlonelinessisthereasocialcure.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3089-httpsfeeds.soundcloud.comstream835434301rcpsychcpdonlinementalhealthtribunalsresponsetothecovid19emergency.mp3.csv
# Processing completed for: 6399-httpsfeeds.soundcloud.comstream835434301-rcpsych-cpdonline-mental-health-tribunals-response-to-the-covid-19-emergency.mp3.csv
# Processing: httpsstatic1.squarespace.comstatic5ce01548eef63e0001b0254dt5ef4fb864e5e6938e548dbcd1594244115669Ian3.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3081-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439334190633connectingthedotswithfranksonder.mp33Fblob_id3D16400096.csv
# Processing completed for: 6385-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53-360439334190633-connecting-the-dots-with-frank-sonder.mp3blob_id=1640.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3090-httpsfeeds.soundcloud.comstream822605398rcpsychcpdonlinecovid19isolationandlonelinessisthereasocialcure.mp3.csv
# Processing completed for: 6403-httpsfeeds.soundcloud.comstream822605398-rcpsych-cpdonline-covid-19-isolation-and-loneliness-is-there-a-social-cure.mp3.csv
# Processing: httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333999464hypnotizeanewperspectiveonacommoninheritanceofallhumanityalbertnerenberg.mp33Fblob_id3D15616355
# Processing: httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333722690sexbusinessartificialintelligenceandshiftinghumanitywithbobbibidochka.mp33Fblob_id3D13875731
# Processing: httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef15c3c092d5e5f26c70ccbmedia.mp3
# Processing: httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef91e2e9b0ba33586a69c6dmedia.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3101-httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef15c3c092d5e5f26c70ccbmedia.mp3.csv
# Processing completed for: 6958-httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef15c3c092d5e5f26c70ccbmedia.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3100-httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef91e2e9b0ba33586a69c6dmedia.mp3.csv
# Processing completed for: 6957-httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef91e2e9b0ba33586a69c6dmedia.mp3.csv
# Processing: httpsmcdn.podbean.commfweb32s8e1KateEp14entrepreneurship101.mp3
# Processing: httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef0147615fe3040f2a9d8a7media.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3102-httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef0147615fe3040f2a9d8a7media.mp3.csv
# Processing completed for: 6959-httpssphinx.acast.compopens5bb3c34841b240784593315fe5ef0147615fe3040f2a9d8a7media.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3096-httpsmcdn.podbean.commfweb32s8e1KateEp14entrepreneurship101.mp3.csv
# Processing completed for: 6407-httpsmcdn.podbean.commfweb32s8e1KateEp14-entrepreneurship101.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3074-httpsstatic1.squarespace.comstatic5ce01548eef63e0001b0254dt5ef4fb864e5e6938e548dbcd1594244115669Ian3.mp3.csv
# Processing completed for: 6769-httpsstatic1.squarespace.comstatic5ce01548eef63e0001b0254dt5ef4fb864e5e6938e548dbcd1594244115669Ian+3.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3083-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333722690sexbusinessartificialintelligenceandshiftinghumanitywithbobbibidochka.mp33Fblob_id3D13875731.csv
# Processing completed for: 6390-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53-360439333722690-sex-business-artificial-intelligence-and-shifting-hum.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3082-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333999464hypnotizeanewperspectiveonacommoninheritanceofallhumanityalbertnerenberg.mp33Fblob_id3D15616355.csv
# Processing completed for: 6387-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53-360439333999464-hypnotize-a-new-perspective-on-a-common-inheritance-o.csv
# Processing: httpsanchor.fms17be1448podcastplay13953581https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20204182F745008184410025824489100f5d.m4a
# Processing: httpsanchor.fms17be1448podcastplay13626536https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20204122F72351935441002c17b8609cfabc.m4a
# Processing: httpsanchor.fmsf2248ccpodcastplay13818440https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204222F75792238441001d8358491edb62.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3103-httpsanchor.fms17be1448podcastplay13953581https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20204182F745008184410025824489100f5d.m4a.csv
# Processing completed for: 6929-httpsanchor.fms17be1448podcastplay13953581httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-4-1874500818-44100-2-5824489100f5d.m4a.csv
# Processing: httpsanchor.fms17be1448podcastplay14290388https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20204262F766604114410029cad3b5b4ed0d.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3104-httpsanchor.fms17be1448podcastplay13626536https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20204122F72351935441002c17b8609cfabc.m4a.csv
# Processing completed for: 6930-httpsanchor.fms17be1448podcastplay13626536httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-4-1272351935-44100-2-c17b8609cfabc.m4a.csv
# Processing: httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333906476thecurrentcrisisandtheroleofhumancapitalpurposeandresiliencepoonambalan.mp33Fblob_id3D14826977
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3105-httpsanchor.fms17be1448podcastplay14290388https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20204262F766604114410029cad3b5b4ed0d.m4a.csv
# Processing completed for: 6928-httpsanchor.fms17be1448podcastplay14290388httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-4-2676660411-44100-2-9cad3b5b4ed0d.m4a.csv
# Processing: httpsanchor.fmsf2248ccpodcastplay13391719https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202011062Ff0918e03d45e9b51fcd53b3e496052d3.m4a
# Processing: httpsanchor.fms17be1448podcastplay14624139https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006022Fc164fc023a8db2c40a9055248f747ce9.m4a
# Processing: httpsanchor.fmsf2248ccpodcastplay14835104https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202011062F503a8d85a6697a0c9728df40dda46543.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3106-httpsanchor.fms17be1448podcastplay14624139https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006022Fc164fc023a8db2c40a9055248f747ce9.m4a.csv
# Processing completed for: 6927-httpsanchor.fms17be1448podcastplay14624139httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-02c164fc023a8db2c40a9055248f747ce9.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3098-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333906476thecurrentcrisisandtheroleofhumancapitalpurposeandresiliencepoonambalan.mp33Fblob_id3D14826977.csv
# Processing completed for: 6388-httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53-360439333906476-the-current-crisis-and-the-role-of-human-capital-purp.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3093-httpsanchor.fmsf2248ccpodcastplay13818440https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204222F75792238441001d8358491edb62.m4a.csv
# Processing completed for: 6395-httpsanchor.fmsf2248ccpodcastplay13818440httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-4-2275792238-44100-1-d8358491edb62.m4a.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3097-httpsanchor.fmsf2248ccpodcastplay13391719https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202011062Ff0918e03d45e9b51fcd53b3e496052d3.m4a.csv
# Processing completed for: 6397-httpsanchor.fmsf2248ccpodcastplay13391719httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-11-06f0918e03d45e9b51fcd53b3e496052d3.m4a.csv
# Processing: httpsanchor.fms18bfaa14podcastplay13793214https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F09fbb02743c695e9b768c4d08c2ea380.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3094-httpsanchor.fmsf2248ccpodcastplay14835104https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202011062F503a8d85a6697a0c9728df40dda46543.m4a.csv
# Processing completed for: 6393-httpsanchor.fmsf2248ccpodcastplay14835104httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-11-06503a8d85a6697a0c9728df40dda46543.m4a.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3114-httpsanchor.fms18bfaa14podcastplay13793214https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F09fbb02743c695e9b768c4d08c2ea380.m4a.csv
# Processing completed for: 6821-httpsanchor.fms18bfaa14podcastplay13793214httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-2009fbb02743c695e9b768c4d08c2ea380.m4.csv
# Processing: httpsanchor.fmse6771f0podcastplay14088011https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204212F7536300048000248e89919792da.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3117-httpsanchor.fmse6771f0podcastplay14088011https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20204212F7536300048000248e89919792da.mp3.csv
# Processing completed for: 6850-httpsanchor.fmse6771f0podcastplay14088011httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-4-2175363000-48000-2-48e89919792da.mp3.csv
# Processing: httpsanchor.fms18bfaa14podcastplay13875803https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F6ce58406c7858f0c951d418aa95c8b93.m4a
# Processing: httpsanchor.fms11d18150podcastplay13312049https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020462F70814013441001839353544b3b3.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3115-httpsanchor.fms18bfaa14podcastplay13875803https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F6ce58406c7858f0c951d418aa95c8b93.m4a.csv
# Processing completed for: 6820-httpsanchor.fms18bfaa14podcastplay13875803httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-206ce58406c7858f0c951d418aa95c8b93.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3113-httpsanchor.fms11d18150podcastplay13312049https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020462F70814013441001839353544b3b3.m4a.csv
# Processing completed for: 6919-httpsanchor.fms11d18150podcastplay13312049httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-4-670814013-44100-1-839353544b3b3.m4a.csv
# Processing: httpsanchor.fms18bfaa14podcastplay13158378https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F151330a71505a64475d150597eb4c41b.m4a
# Processing: httpschtbl.comtrackECD162episodes.castos.com5fc7f85ae73a53360439333584479beyondtheshamanpart2adeconstructionwithhauxita.mp33Fblob_id3D13439632
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3118-httpsanchor.fms18bfaa14podcastplay13158378https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F151330a71505a64475d150597eb4c41b.m4a.csv
# Processing completed for: 6827-httpsanchor.fms18bfaa14podcastplay13158378httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-20151330a71505a64475d150597eb4c41b.m4.csv
# Processing: httpsanchor.fms17be1448podcastplay13298976https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F2020442F70231979441002a4a22fd3de94f.m4a
# Processing: httpsanchor.fms18bfaa14podcastplay13369703https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F3b7698adaf3350b3215a94e018fb26d9.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3116-httpsanchor.fms18bfaa14podcastplay13369703https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202108202F3b7698adaf3350b3215a94e018fb26d9.m4a.csv
# Processing completed for: 6826-httpsanchor.fms18bfaa14podcastplay13369703httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-08-203b7698adaf3350b3215a94e018fb26d9.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/3111-httpsanchor.fms17be1448podcastplay13298976https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F2020442F70231979441002a4a22fd3de94f.m4a.csv
# Processing completed for: 6931-httpsanchor.fms17be1448podcastplay13298976httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-4-470231979-44100-2-a4a22fd3de94f.m4a.csv
# Processing: httpspdcn.coemcdn.podbean.commfwebhno0omcheron_k_griffin_blm_9eqsw.mp3
# Processing: httpshayarthur.comwpcontentuploadssites3202006Shayspodcasthonesty6_4_203.12PM.mp3
# ...
# Processing: httpsanchor.fms143be7dcpodcastplay15676956https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205252F851193754800026b7c2e4d2111a.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4496-httpmedia.blubrry.com408427lennondesignllc.comwpcontentaudiocre8tivitycre8tivityep097.mp3.csv
# Processing completed for: 9564-httpmedia.blubrry.com408427lennondesignllc.comwp-contentaudiocre8tivitycre8tivity-ep097.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4534-httpsanchor.fms143be7dcpodcastplay15676956https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205252F851193754800026b7c2e4d2111a.mp3.csv
# Processing: httpsanchor.fmsd3f5fccpodcastplay15689329https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205252F851802734800014ce70d75ff1bd.mp3
# Processing completed for: 9847-httpsanchor.fms143be7dcpodcastplay15676956httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-2585119375-48000-2-6b7c2e4d2111a.mp.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4544-httpsanchor.fmsd3f5fccpodcastplay15689329https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205252F851802734800014ce70d75ff1bd.mp3.csv
# Processing completed for: 9865-httpsanchor.fmsd3f5fccpodcastplay15689329httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-2585180273-48000-1-4ce70d75ff1bd.mp3.csv
# Processing: httpsanchor.fmsd3f5fccpodcastplay14736264https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020542F79469531480001f22cbfae29c5f.mp3
# Processing: httpsanchor.fmsd3f5fccpodcastplay14736297https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020542F794695414800017507890d28c6e.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4546-httpsanchor.fmsd3f5fccpodcastplay14736264https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020542F79469531480001f22cbfae29c5f.mp3.csv
# Processing completed for: 9886-httpsanchor.fmsd3f5fccpodcastplay14736264httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-479469531-48000-1-f22cbfae29c5f.mp3.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4545-httpsanchor.fmsd3f5fccpodcastplay14736297https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020542F794695414800017507890d28c6e.mp3.csv
# Processing completed for: 9885-httpsanchor.fmsd3f5fccpodcastplay14736297httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-479469541-48000-1-7507890d28c6e.mp3.csv
# Processing: httpscivillyspeaking.files.wordpress.com202004mclafferty_may.mp3
# Processing: httpsclovermedia.s3uswest2.amazonaws.comstore7badd4defea04ca2856093efc1430b50bfcf4099c8audio.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4547-httpsclovermedia.s3uswest2.amazonaws.comstore7badd4defea04ca2856093efc1430b50bfcf4099c8audio.mp3.csv
# Processing completed for: 9846-httpsclovermedia.s3-us-west-2.amazonaws.comstore7badd4de-fea0-4ca2-8560-93efc1430b50bfcf4099c8audio.mp3.csv
# Processing: httpsanchor.fmsd3f5fccpodcastplay15363181https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205182F83308134480001624f19c081ee5.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4548-httpsanchor.fmsd3f5fccpodcastplay15363181https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205182F83308134480001624f19c081ee5.mp3.csv
# Processing completed for: 9868-httpsanchor.fmsd3f5fccpodcastplay15363181httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-1883308134-48000-1-624f19c081ee5.mp3.csv
# Processing: httpsanchor.fmsd3f5fccpodcastplay14736383https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020542F7946954248000131f3dd685e25d.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4549-httpsanchor.fmsd3f5fccpodcastplay14736383https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020542F7946954248000131f3dd685e25d.mp3.csv
# Processing completed for: 9884-httpsanchor.fmsd3f5fccpodcastplay14736383httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-479469542-48000-1-31f3dd685e25d.mp3.csv
# Processing: httpsanchor.fmsd3f5fccpodcastplay15689257https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205252F851802704800019bdcdad38c61a.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4550-httpsanchor.fmsd3f5fccpodcastplay15689257https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205252F851802704800019bdcdad38c61a.mp3.csv
# Processing completed for: 9867-httpsanchor.fmsd3f5fccpodcastplay15689257httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-2585180270-48000-1-9bdcdad38c61a.mp3.csv
# Processing: httpmedia.blubrry.com408427lennondesignllc.comwpcontentaudiocre8tivitycre8tivityep091.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4520-httpscivillyspeaking.files.wordpress.com202004mclafferty_may.mp3.csv
# Processing completed for: 9714-httpscivillyspeaking.files.wordpress.com202004mclafferty_may.mp3.csv
# Processing: httpsanchor.fmsd3f5fccpodcastplay15036518https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205112F81354820480001fc2b8d2fac522.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4553-httpsanchor.fmsd3f5fccpodcastplay15036518https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205112F81354820480001fc2b8d2fac522.mp3.csv
# Processing completed for: 9876-httpsanchor.fmsd3f5fccpodcastplay15036518httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-1181354820-48000-1-fc2b8d2fac522.mp3.csv
# Processing: httpmedia.blubrry.com408427lennondesignllc.comwpcontentaudiocre8tivitycre8tivityep092.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4506-httpmedia.blubrry.com408427lennondesignllc.comwpcontentaudiocre8tivitycre8tivityep091.mp3.csv
# Processing completed for: 9569-httpmedia.blubrry.com408427lennondesignllc.comwp-contentaudiocre8tivitycre8tivity-ep091.mp3.csv
# Processing: httpsanchor.fmsdc6f15d0podcastplay66484899https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20232132F3177887114410026e7f669acbe1b109.mp3
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4554-httpsanchor.fmsdc6f15d0podcastplay66484899https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F20232132F3177887114410026e7f669acbe1b109.mp3.csv
# Processing completed for: 9733-httpsanchor.fmsdc6f15d0podcastplay66484899httpsd3ctxlq1ktw2nl.cloudfront.netstaging2023-2-13317788711-44100-2-6e7f669acbe1b109.m.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4507-httpmedia.blubrry.com408427lennondesignllc.comwpcontentaudiocre8tivitycre8tivityep092.mp3.csv
# Processing completed for: 9568-httpmedia.blubrry.com408427lennondesignllc.comwp-contentaudiocre8tivitycre8tivity-ep092.mp3.csv
# Processing: httpsanchor.fms1e2cec78podcastplay14969817https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205102F809406784410026afd9677875d4.mp3
# Processing: httpsmcdn.podbean.commfweblxgkjlEp33_VirtualOpenHouseTips_FINAL.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4555-httpsmcdn.podbean.commfweblxgkjlEp33_VirtualOpenHouseTips_FINAL.m4a.csv
# Processing completed for: 9706-httpsmcdn.podbean.commfweblxgkjlEp33_VirtualOpenHouseTips_FINAL.m4a.csv
# Error processing 9721-httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm0cd0f9440e60f5dc.mp3.csv: Error opening '/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm0cd0f9440e60f5dc.mp3.wav': System error.
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4538-httpsanchor.fms1e2cec78podcastplay14969817https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205102F809406784410026afd9677875d4.mp3.csv
# Processing completed for: 9850-httpsanchor.fms1e2cec78podcastplay14969817httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-1080940678-44100-2-6afd9677875d4.mp.csv
# Processing: httpscivillyspeaking.files.wordpress.com202006ingraham_june.mp3
# Processing: httpsanchor.fms1301ee84podcastplay13660111https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282F36235319ded3543bc7168774ca720817.m4a
# Processing: httpsmcdn.podbean.commfweb1ev1cdEp35_AreYouPreparedFINAL_atf5i.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4560-httpsmcdn.podbean.commfweb1ev1cdEp35_AreYouPreparedFINAL_atf5i.m4a.csv
# Processing completed for: 9704-httpsmcdn.podbean.commfweb1ev1cdEp35_AreYouPreparedFINAL_atf5i.m4a.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4556-httpscivillyspeaking.files.wordpress.com202006ingraham_june.mp3.csv
# Processing completed for: 9713-httpscivillyspeaking.files.wordpress.com202006ingraham_june.mp3.csv
# Processing: httpsanchor.fms11166de8podcastplay15174031https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205142F821940414410011aa5bd69de04b.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4539-httpsanchor.fms1301ee84podcastplay13660111https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282F36235319ded3543bc7168774ca720817.m4a.csv
# Processing completed for: 9862-httpsanchor.fms1301ee84podcastplay13660111httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-2836235319ded3543bc7168774ca720817.m4.csv
# Processing: httpsanchor.fms1e402cfcpodcastplay14493049https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006022Fca4c32db55f8d45ce13ec6bdfca9e65c.m4a
# Error processing 9716-httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm7270783e5cf174f6.mp3.csv: Error opening '/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm7270783e5cf174f6.mp3.wav': System error.
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4562-httpsanchor.fms1e402cfcpodcastplay14493049https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006022Fca4c32db55f8d45ce13ec6bdfca9e65c.m4a.csv
# Processing completed for: 9702-httpsanchor.fms1e402cfcpodcastplay14493049httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-02ca4c32db55f8d45ce13ec6bdfca9e65c.m4.csv
# Processing: httpsanchor.fms1301ee84podcastplay14925780https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282Fb2f689f265e4f7363e5c38449822fb07.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4557-httpsanchor.fms11166de8podcastplay15174031https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F20205142F821940414410011aa5bd69de04b.m4a.csv
# Processing completed for: 9707-httpsanchor.fms11166de8podcastplay15174031httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-5-1482194041-44100-1-1aa5bd69de04b.m4.csv
# Error processing 9717-httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fmbc7efb45ebbd049c.mp3.csv: Error opening '/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fmbc7efb45ebbd049c.mp3.wav': System error.
# Error processing 9719-httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm891323a2a435cc8e.mp3.csv: Error opening '/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm891323a2a435cc8e.mp3.wav': System error.
# Processing: httpsanchor.fms1301ee84podcastplay13446881https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282F688b4026f2b580869c4cd505627f3270.m4a
# Processing: httpsanchor.fms1301ee84podcastplay14708721https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282F6eb90a41fcca466562baf7b8d8b814b3.m4a
# Processing: httpsspecialfeaturespodcast.podomatic.comenclosure20200505T04_56_4607_00.mp3_1588679864.14797737
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4541-httpsanchor.fms1301ee84podcastplay14925780https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282Fb2f689f265e4f7363e5c38449822fb07.m4a.csv
# Processing completed for: 9858-httpsanchor.fms1301ee84podcastplay14925780httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-28b2f689f265e4f7363e5c38449822fb07.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4542-httpsanchor.fms1301ee84podcastplay13446881https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282F688b4026f2b580869c4cd505627f3270.m4a.csv
# Processing completed for: 9863-httpsanchor.fms1301ee84podcastplay13446881httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-28688b4026f2b580869c4cd505627f3270.m4.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4540-httpsanchor.fms1301ee84podcastplay14708721https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202006282F6eb90a41fcca466562baf7b8d8b814b3.m4a.csv
# Processing completed for: 9859-httpsanchor.fms1301ee84podcastplay14708721httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-06-286eb90a41fcca466562baf7b8d8b814b3.m4.csv
# Processing: httpsanchor.fms1301ee84podcastplay14335259https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202110022F21f905a1b0fa140cf04e22933d855e28.m4a
# Processing: httpsanchor.fms1301ee84podcastplay15724680https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202007172F8feaaba0c45262e2edf1402440bae410.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4561-httpsspecialfeaturespodcast.podomatic.comenclosure20200505T04_56_4607_00.mp3_1588679864.14797737.csv
# Processing completed for: 9712-httpsspecialfeaturespodcast.podomatic.comenclosure2020-05-05T04_56_46-07_00.mp3_=1588679864.14797737.csv
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4552-httpsanchor.fms1301ee84podcastplay14335259https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202110022F21f905a1b0fa140cf04e22933d855e28.m4a.csv
# Processing completed for: 9860-httpsanchor.fms1301ee84podcastplay14335259httpsd3ctxlq1ktw2nl.cloudfront.netstaging2021-10-0221f905a1b0fa140cf04e22933d855e28.m4.csv
# Error processing 9718-httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm06c6d374b2559299.mp3.csv: Error opening '/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm06c6d374b2559299.mp3.wav': System error.
# Error processing 9715-httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fmd6e01f3987e0f21e.mp3.csv: Error opening '/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fmd6e01f3987e0f21e.mp3.wav': System error.
# Processing: httpsanchor.fms11166de8podcastplay13202188https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020422F6956564344100166a86b4642642.m4a
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4543-httpsanchor.fms1301ee84podcastplay15724680https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202007172F8feaaba0c45262e2edf1402440bae410.m4a.csv
# Processing completed for: 9856-httpsanchor.fms1301ee84podcastplay15724680httpsd3ctxlq1ktw2nl.cloudfront.netstaging2020-07-178feaaba0c45262e2edf1402440bae410.m4.csv
# Error processing 9720-httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm16167cc6002fa517.mp3.csv: Error opening '/shared/3/projects/bangzhao/prosodic_embeddings/merge/temp/httpschrt.fmtrack641E8Ba.pdcst.tox9Qo81zX35Nprjibmedia.transistor.fm16167cc6002fa517.mp3.wav': System error.
# Saved merged file: /shared/3/projects/bangzhao/prosodic_embeddings/merge/output/4571-httpsanchor.fms11166de8podcastplay13202188https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fproduction2F2020422F6956564344100166a86b4642642.m4a.csv
# Processing completed for: 9710-httpsanchor.fms11166de8podcastplay13202188httpsd3ctxlq1ktw2nl.cloudfront.netproduction2020-4-269565643-44100-1-66a86b4642642.m4a.csv
# Processing: httpstraffic.libsyn.comsecuretherewasasale43_TWAS_43__Watchmen.mp3destid633781
# Processing: httpsanchor.fms16654468podcastplay13851253https3A2F2Fd3ctxlq1ktw2nl.cloudfront.net2Fstaging2F202005162Fbc075b82e440cb275ec3d539fed21f81.m4a

# %%
for i, filename in enumerate(os.listdir(transcript_path)):
    if filename.endswith(".csv"):

        # Get the metadata
        line = int(filename.split('-')[0]) + 1
        metadata = read_nth_line_as_json(metadata_path, line)
        
        # Get the standard name
        new_name = standardize_name(metadata['enclosure'])
        
        # download mp3 from URL and convert to WAV
        wav_file_path = os.path.join(download_directory, new_name + '.wav')
        download_and_convert(metadata, new_name, download_directory)
    
        # Get prosody
        prosodydf = extract_prosody(wav_file_path, download_directory+new_name)
    
        # Read transcript
        file_path = os.path.join(transcript_path, filename)
        transcriptdf = pd.read_csv(file_path)
        
        # Merge Prosody and transcript
        merge_prosody_transcript(prosodydf, transcriptdf, new_name, i, output_directory)

        # Remove the WAV file after merging
        if os.path.exists(wav_file_path):
            os.remove(wav_file_path)
